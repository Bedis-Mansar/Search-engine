# %%
from sklearn.decomposition import PCA
import pickle
import matplotlib.pyplot as plt
import numpy as np
from sklearn.neighbors import NearestNeighbors
import pandas as pd
import requests
import PIL.Image
from io import BytesIO
from keras.preprocessing import image
from keras.preprocessing.image import load_img
from keras.applications.vgg16 import preprocess_input
from keras.models import Model
from keras.applications import vgg16
import tensorflow as tf
from elasticsearch import Elasticsearch
import json
from IPython.display import Image, display, Markdown, Code, HTML

# %%
try:
    # Disable all GPUS
    tf.config.set_visible_devices([], 'GPU')
    visible_devices = tf.config.get_visible_devices()
    for device in visible_devices:
        assert device.device_type != 'GPU'
except:
    # Invalid device or cannot modify virtual devices once initialized.
    pass

# %%
es = Elasticsearch('127.0.0.1', port=9200)

# %%
index = 'indexproject'
source_no_vecs = ['imageId','tags', 'imgUrl']

# %%
es.indices.delete(index)
# Out:
# c:\users\bedis\appdata\local\programs\python\python36\lib\site-packages\elasticsearch\connection\base.py:208: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.14/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-5-bcc16245c8da> in <module>
# ----> 1 es.indices.delete(index)
#
# c:\users\bedis\appdata\local\programs\python\python36\lib\site-packages\elasticsearch\client\utils.py in _wrapped(*args, **kwargs)
#     166                 if p in kwargs:
#     167                     params[p] = kwargs.pop(p)
# --> 168             return func(*args, params=params, headers=headers, **kwargs)
#     169
#     170         return _wrapped
#
# c:\users\bedis\appdata\local\programs\python\python36\lib\site-packages\elasticsearch\client\indices.py in delete(self, index, params, headers)
#     295
#     296         return self.transport.perform_request(
# --> 297             "DELETE", _make_path(index), params=params, headers=headers
#     298         )
#     299
#
# c:\users\bedis\appdata\local\programs\python\python36\lib\site-packages\elasticsearch\transport.py in perform_request(self, method, url, headers, params, body)
#     456                         raise e
#     457                 else:
# --> 458                     raise e
#     459
#     460             else:
#
# c:\users\bedis\appdata\local\programs\python\python36\lib\site-packages\elasticsearch\transport.py in perform_request(self, method, url, headers, params, body)
#     424                     headers=headers,
#     425                     ignore=ignore,
# --> 426                     timeout=timeout,
#     427                 )
#     428
#
# c:\users\bedis\appdata\local\programs\python\python36\lib\site-packages\elasticsearch\connection\http_urllib3.py in perform_request(self, method, url, params, body, timeout, ignore, headers)
#     275                 method, full_url, url, orig_body, duration, response.status, raw_data
#     276             )
# --> 277             self._raise_error(response.status, raw_data)
#     278
#     279         self.log_request_success(
#
# c:\users\bedis\appdata\local\programs\python\python36\lib\site-packages\elasticsearch\connection\base.py in _raise_error(self, status_code, raw_data)
#     329
#     330         raise HTTP_EXCEPTIONS.get(status_code, TransportError)(
# --> 331             status_code, error_message, additional_info
#     332         )
#     333
#
# NotFoundError: NotFoundError(404, 'index_not_found_exception', 'no such index [indexproject]', indexproject, index_or_alias)

# %%
settings = {
  "settings": {
    "elastiknn": True,
    "number_of_shards": 1,
    "number_of_replicas": 0
  }
}

mapping = {
  "dynamic": False,
  "properties": {
      "imageId": { "type": "keyword" },
      "featurevector": {
          "type": "elastiknn_dense_float_vector",
          "elastiknn": {
            "dims": 795,
            "model": "lsh",
            "similarity": "l2",
            "L": 60,
            "k": 3,
            "w": 2
          }
    },
    "tags": { "type": "text" },
    "imgUrl":{"type":"text","index":False}
  }
}


if not es.indices.exists(index):
    es.indices.create(index, json.dumps(settings))
    es.indices.put_mapping(json.dumps(mapping), index)
es.indices.get_mapping(index)
# Out:
# {'indexproject': {'mappings': {'dynamic': 'false',
#    'properties': {'featurevector': {'type': 'elastiknn_dense_float_vector',
#      'elastiknn': {'model': 'lsh',
#       'similarity': 'l2',
#       'dims': 795,
#       'L': 60,
#       'k': 3,
#       'w': 2}},
#     'imageId': {'type': 'keyword'},
#     'imgUrl': {'type': 'text', 'index': False},
#     'tags': {'type': 'text'}}}}}

# %%
with open('C:/Users/bedis/Desktop/pkl2/L.pkl', 'rb') as f:
   L = pickle.load(f)
with open('C:/Users/bedis/Desktop/pkl2/Lindice.pkl', 'rb') as f:
   Lindice= pickle.load(f)
with open('C:/Users/bedis/Desktop/pkl1/PCA795.pkl', 'rb') as f:
   PCA = pickle.load(f)

# %%
df=pd.read_csv('C:/Users/bedis/Desktop/flickr/cbir/photo_metadata/resultat2.csv',dtype={'id': str})

# %%
def image_actions():
    
    for i in Lindice:
        
        link="https://live.staticflickr.com/{x}/{y}_{z}.jpg".format(x=df.iloc[i]['flickr_server'],y=df.iloc[i]['id'],z=df.iloc[i]['flickr_secret'])
        yield {
              "_op_type": "index", "_index": index, "_id": df.iloc[i]["id"],
               "tags":df.iloc[i]['tags'],

              "imgUrl": link
            }

# %%
from elasticsearch.helpers import bulk
bulk(es, image_actions(), chunk_size=2000, max_retries=2)
# Out:
# (108627, [])

# %%
es.indices.refresh(index=index)
es.indices.forcemerge(index=index, max_num_segments=1, request_timeout=300)
# Out:
# {'_shards': {'total': 1, 'successful': 1, 'failed': 0}}

# %%
model = vgg16.VGG16(weights='imagenet', include_top=True)

# %%
L=PCA.transform(L)
def feature_extractor(img):
    x = np.expand_dims(img, axis=0)
    x = preprocess_input(x)
    
    model_extractfeatures = Model(inputs=model.input, outputs=model.get_layer('fc1').output)
    fc2_features = model_extractfeatures.predict(x)[0]
    
    
    return fc2_features/np.linalg.norm(fc2_features)

# %%
def vector_action():
    
    for i in range(len(Lindice)):
        
        try:
            
            

            p=L[i]
            yield { "_op_type": "update", "_index": index, "_id": df.iloc[Lindice[i]]["id"], 
                "doc": { 
                  "featurevector": { "values": p.tolist()}
                }}
        except:
            pass

# %%
bulk(es, vector_action(), chunk_size=2000, max_retries=2)
# Out:
# c:\users\bedis\appdata\local\programs\python\python36\lib\site-packages\elasticsearch\connection\base.py:208: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.14/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)
# (108627, [])

# %%
es.indices.refresh(index=index)
es.indices.forcemerge(index=index, max_num_segments=1, request_timeout=1200)
# Out:
# {'_shards': {'total': 1, 'successful': 1, 'failed': 0}}

# %%
def display_hits(res):
    print(f"Found {res['hits']['total']['value']} hits in {res['took']} ms. Showing top {len(res['hits']['hits'])}.")
    print("")
    for hit in res['hits']['hits']:
        try:
            s = hit['_source']
            print(f"Title   {s.get('title', None)}")
            if 'tags' in s:
              desc = str(s.get('tags', None))
              print(f"Desc    {desc[:80] + ('...' if len(desc) > 80 else '')}")
            if 'price' in s:
              print(f"Labels   {s['labels']}")
            print(f"ID      {s.get('imageId', None)}")
            print(f"Score   {hit.get('_score', None)}")
            display(Image(s.get("imgUrl"), width=128))
            print("")
        except:
            pass

# %%
def search_by_image_query(image_id=None, feature_vector=None,size=10):
    if image_id==None and feature_vector==None:
        raise ValueError("Please enter an Image ID or a Feature Vector")
    
    if image_id:
            body = {
              "query": {
                "elastiknn_nearest_neighbors": {
                    "field": "featureVec",
                    "vec": {
                    "index": index,
                    "field": "featureVec",
                    "id": image_id
                  },
                  "model": "lsh",
                  "similarity": "l2",
                  "candidates": 100
                }
              }
            }
        
    elif feature_vector:
        body = {
            "query":{
            "elastiknn_nearest_neighbors": {
              "field": "featurevector",
              "vec": {
                "values": feature_vector
              },
              "model": "lsh",
              "similarity": "l2",
              "candidates": 100
            }
          }
        }
    
    res = es.search(index=index, body=body, size=size, _source=source_no_vecs)
    display_hits(res)

# %%
model = vgg16.VGG16(weights='imagenet', include_top=True)

# %%
img = load_img('C:/Users/bedis/Desktop/tokyo.jpg')
img = img.resize((224, 224))
img = image.img_to_array(img)
x = np.expand_dims(img, axis=0)
x = preprocess_input(x)
    
model_extractfeatures = Model(inputs=model.input, outputs=model.get_layer('fc1').output)
fc2_features = model_extractfeatures.predict(x)[0]
    
    
fc2_features=fc2_features/np.linalg.norm(fc2_features)
feature=fc2_features.tolist()
feature=PCA.transform(fc2_features.reshape(1,-1))[0].tolist()

# %%
search_by_image_query(feature_vector=feature)
# Out:
# c:\users\bedis\appdata\local\programs\python\python36\lib\site-packages\elasticsearch\connection\base.py:208: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.14/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)
# Found 100 hits in 1127 ms. Showing top 10.
#
# Title   None
# Desc    {iphone,iflickr,通化街,iphonecamera}
# ID      None
# Score   0.6390207
# Title   None
# Desc    {}
# ID      None
# Score   0.63150555
# Title   None
# Desc    {city,urban,japan,tokyo,spring,shinjuku,neon,nighttime,2008,macdonalds,urbanland...
# ID      None
# Score   0.62490654
# Title   None
# Desc    {sanfrancisco,california,november,nikon,chinatown,dslr,2008,d80}
# ID      None
# Score   0.6197129
# Title   None
# Desc    {copenhagen,mac,mcdonalds,burgerking,canon5d,københavn,rådhuspladsen,2470l28,voe...
# ID      None
# Score   0.6108719
# Title   None
# Desc    {trip,vacation,newyork,2006,timesquare,2006newyorktrip}
# ID      None
# Score   0.60987157
# Title   None
# Desc    {}
# ID      None
# Score   0.60726225
# Title   None
# Desc    {winter,summer,mountain,snow,ski,france,alps,ice,car,bike,les,montagne,alpes,fre...
# ID      None
# Score   0.6035965
# Title   None
# Desc    {newyork,night,blog,manhattan,timesquare,website,canon5dmkii}
# ID      None
# Score   0.60024256
# Title   None
# Desc    {}
# ID      None
# Score   0.59583396

# %%
def search_by_query(q,size=5):
    body = {
        "query":{"multi_match": {
          "query": q,
          "fields": ["tags"]
        }
      }
    }

    res = es.search(index=index, body=body, size=size, _source=source_no_vecs)
    display_hits(res)

# %%
search_by_query("france")
# Out:
# Found 1821 hits in 37 ms. Showing top 5.
#
# Title   None
# Desc    {france}
# ID      None
# Score   6.221834
# Title   None
# Desc    {france}
# ID      None
# Score   6.221834
# Title   None
# Desc    {france}
# ID      None
# Score   6.221834
# Title   None
# Desc    {france}
# ID      None
# Score   6.221834
# Title   None
# Desc    {france}
# ID      None
# Score   6.221834

# %%
def combined_search(q,image_id=None,feature_vector=None,size=5):
    if image_id==None and feature_vector==None:
        raise ValueError("Please enter an Image ID or a Feature Vector")
    if image_id:
        fetch_res = es.get(index=index, id=image_id)
        query_vec = fetch_res['_source']['featureVec']['values']
        query = {
            "function_score": {
              "query": {
                "bool": {
                  "filter": {
                    "exists": {
                      "field": "featureVec"
                    }
                  },
                  "must": {
                    "multi_match": {
                      "query": q,
                      "fields": ["tags"]
                    }
                  }
                }
              },
              "boost_mode": "replace",
              "functions": [{
                "elastiknn_nearest_neighbors": {
                  "field": "featureVec",
                  "similarity": "l2",
                  "model": "lsh",
                  "candidates": 100,
                  "vec": {
                    "values": query_vec
                  }
                },
                "weight": 2
              }]
            }
          }
    elif feature_vector:
        body={"query": {
            "function_score": {
              "query": {
                "bool": {
                  "filter": {
                    "exists": {
                      "field": "featureVec"
                    }
                  },
                  "must": {
                    "multi_match": {
                      "query": q,
                      "fields": ["tags"]
                    }
                  }
                }
              },
              "boost_mode": "replace",
              "functions": [{
                "elastiknn_nearest_neighbors": {
                  "field": "featureVec",
                  "similarity": "l2",
                  "model": "lsh",
                  "candidates": 100,
                  "vec": {
                    "values": feature_vector
                  }
                },
                "weight": 2
              }]
            }
          }
             }

    res = es.search(index=index, body=body, size=size, _source=source_no_vecs)
    display_hits(res)

# %%
combined_search(q="city",feature_vector=feature)
# Out:
# Found 1847 hits in 59 ms. Showing top 5.
#
# Title   None
# Desc    {city,urban,japan,tokyo,spring,shinjuku,neon,nighttime,2008,macdonalds,urbanland...
# ID      None
# Score   0.8666667
# Title   None
# Desc    {city,newyork,film,35mm,lights,downtown,taxis,uptown,zenit,ttl,february,crosswal...
# ID      None
# Score   0.8666667
# Title   None
# Desc    {city,urban,berlin,canon,germany,deutschland,noche,canon20d,alemania,nicht,alema...
# ID      None
# Score   0.8333333
# Title   None
# Desc    {road,city,storm,car,rainbow,singapore,cloudy,e300,raining,zd,1445mm,anawesomesh...
# ID      None
# Score   0.8333333
# Title   None
# Desc    {life,california,road,county,ca,street,camera,city,light,red,building,cars,ferry...
# ID      None
# Score   0.8333333
